# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df =pd.read_csv('IBMD Movie dataset.txt',delimiter = ',')

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.sort_values('Rating', ascending = False)
# Out:
#      Rank                    Title                     Genre  \
# 54     55          The Dark Knight        Action,Crime,Drama
# 80     81                Inception   Action,Adventure,Sci-Fi
# 117   118                   Dangal    Action,Biography,Drama
# 36     37             Interstellar    Adventure,Drama,Sci-Fi
# 96     97            Kimi no na wa   Animation,Drama,Fantasy
# ..    ...                      ...                       ...
# 968   969                  Wrecker    Action,Horror,Thriller
# 647   648                 Tall Men   Fantasy,Horror,Thriller
# 871   872     Dragonball Evolution  Action,Adventure,Fantasy
# 42     43  Don't Fuck in the Woods                    Horror
# 829   830           Disaster Movie                    Comedy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# ...

# %%
df['Actors'].nunqiue()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a0ceca44cf63> in <module>
# ----> 1 df['Actors'].nunqiue()
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'nunqiue'

# %% [markdown]
# df.corr(method = 'pearson')
# df.corr(method = 'kendall')

# %%
df['Actors'].unique()
# Out:
# array(['Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana',
#        'Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron',
#        'James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula',
#        'Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson',
#        'Will Smith, Jared Leto, Margot Robbie, Viola Davis',
#        'Matt Damon, Tian Jing, Willem Dafoe, Andy Lau',
#        'Ryan Gosling, Emma Stone, Rosemarie DeWitt, J.K. Simmons',
#        'Essie Davis, Andrea Riseborough, Julian Barratt,Kenneth Branagh',
#        'Charlie Hunnam, Robert Pattinson, Sienna Miller, Tom Holland',
#        'Jennifer Lawrence, Chris Pratt, Michael Sheen,Laurence Fishburne',
#        'Eddie Redmayne, Katherine Waterston, Alison Sudol,Dan Fogler',
#        'Taraji P. Henson, Octavia Spencer, Janelle Monáe,Kevin Costner',
#        'Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen',
# ...

# %%
list1 = [] # ist we create an empty list 
for value in df['Actors']: # we call the values inside the df['Genre']
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Chris Pratt', ' Vin Diesel', ' Bradley Cooper', ' Zoe Saldana'],
#  ['Noomi Rapace',
#   ' Logan Marshall-Green',
#   ' Michael Fassbender',
#   ' Charlize Theron'],
#  ['James McAvoy', ' Anya Taylor-Joy', ' Haley Lu Richardson', ' Jessica Sula'],
#  ['Matthew McConaughey',
#   'Reese Witherspoon',
#   ' Seth MacFarlane',
#   ' Scarlett Johansson'],
#  ['Will Smith', ' Jared Leto', ' Margot Robbie', ' Viola Davis'],
#  ['Matt Damon', ' Tian Jing', ' Willem Dafoe', ' Andy Lau'],
#  ['Ryan Gosling', ' Emma Stone', ' Rosemarie DeWitt', ' J.K. Simmons'],
#  ['Essie Davis', ' Andrea Riseborough', ' Julian Barratt', 'Kenneth Branagh'],
#  ['Charlie Hunnam', ' Robert Pattinson', ' Sienna Miller', ' Tom Holland'],
#  ['Jennifer Lawrence', ' Chris Pratt', ' Michael Sheen', 'Laurence Fishburne'],
#  ['Eddie Redmayne', ' Katherine Waterston', ' Alison Sudol', 'Dan Fogler'],
#  ['Taraji P. Henson', ' Octavia Spencer', ' Janelle Monáe', 'Kevin Costner'],
# ...

# %%
one_d = [] # ist we create an empty list 
for item in list1: # we call the values inside the created list1 above
    for item1 in item: ## then we call the items in te 2D out
        one_d.append(item1)

# %%
one_d
# Out:
# ['Chris Pratt',
#  ' Vin Diesel',
#  ' Bradley Cooper',
#  ' Zoe Saldana',
#  'Noomi Rapace',
#  ' Logan Marshall-Green',
#  ' Michael Fassbender',
#  ' Charlize Theron',
#  'James McAvoy',
#  ' Anya Taylor-Joy',
#  ' Haley Lu Richardson',
#  ' Jessica Sula',
#  'Matthew McConaughey',
#  'Reese Witherspoon',
#  ' Seth MacFarlane',
#  ' Scarlett Johansson',
#  'Will Smith',
#  ' Jared Leto',
#  ' Margot Robbie',
#  ' Viola Davis',
#  'Matt Damon',
#  ' Tian Jing',
#  ' Willem Dafoe',
#  ' Andy Lau',
#  'Ryan Gosling',
#  ' Emma Stone',
#  ' Rosemarie DeWitt',
#  ' J.K. Simmons',
#  'Essie Davis',
#  ' Andrea Riseborough',
#  ' Julian Barratt',
#  'Kenneth Branagh',
#  'Charlie Hunnam',
#  ' Robert Pattinson',
#  ' Sienna Miller',
#  ' Tom Holland',
#  'Jennifer Lawrence',
#  ' Chris Pratt',
#  ' Michael Sheen',
#  'Laurence Fishburne',
#  'Eddie Redmayne',
#  ' Katherine Waterston',
#  ' Alison Sudol',
#  'Dan Fogler',
#  'Taraji P. Henson',
#  ' Octavia Spencer',
# ...

# %%
one_dd = pd.DataFrame(one_d)
list(one_dd[0].unique())
# Out:
# ['Chris Pratt',
#  ' Vin Diesel',
#  ' Bradley Cooper',
#  ' Zoe Saldana',
#  'Noomi Rapace',
#  ' Logan Marshall-Green',
#  ' Michael Fassbender',
#  ' Charlize Theron',
#  'James McAvoy',
#  ' Anya Taylor-Joy',
#  ' Haley Lu Richardson',
#  ' Jessica Sula',
#  'Matthew McConaughey',
#  'Reese Witherspoon',
#  ' Seth MacFarlane',
#  ' Scarlett Johansson',
#  'Will Smith',
#  ' Jared Leto',
#  ' Margot Robbie',
#  ' Viola Davis',
#  'Matt Damon',
#  ' Tian Jing',
#  ' Willem Dafoe',
#  ' Andy Lau',
#  'Ryan Gosling',
#  ' Emma Stone',
#  ' Rosemarie DeWitt',
#  ' J.K. Simmons',
#  'Essie Davis',
#  ' Andrea Riseborough',
#  ' Julian Barratt',
#  'Kenneth Branagh',
#  'Charlie Hunnam',
#  ' Robert Pattinson',
#  ' Sienna Miller',
#  ' Tom Holland',
#  'Jennifer Lawrence',
#  ' Chris Pratt',
#  ' Michael Sheen',
#  'Laurence Fishburne',
#  'Eddie Redmayne',
#  ' Katherine Waterston',
#  ' Alison Sudol',
#  'Dan Fogler',
#  'Taraji P. Henson',
#  ' Octavia Spencer',
# ...

# %%
df['Actors'].duplicated().sum()
# Out:
# 4

# %%
df['Actors'].sort_values()
# Out:
# 765    Aamir Khan, Anushka Sharma, Sanjay Dutt,Boman ...
# 430      Aamir Khan, Madhavan, Mona Singh, Sharman Joshi
# 117    Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...
# 535    Aaron Paul, Dominic Cooper, Imogen Poots, Scot...
# 97     Aaron Poole, Kenneth Welsh,Daniel Fathers, Kat...
#                              ...
# 141    Zachary Gordon, Robert Capron, Rachael Harris,...
# 30     Zoey Deutch, James Franco, Tangie Ambrose,Cedr...
# 649    Zoey Deutch, Lucy Fry, Danila Kozlovsky, Gabri...
# 928    Zoey Deutch, Nicholas Braun, Mateo Arias, Isra...
# 507    Zooey Deschanel, Joseph Gordon-Levitt, Geoffre...
# Name: Actors, Length: 1000, dtype: object

# %%
df.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0

# %%
plt.figure(figsize = (20,4))

df.corr().plot()
plt.xticks(rotation = 'vertical')
plt.show()

# %%
plt.figure(figsize = (9,4))


plt.scatter(df['Rating'], df['Runtime (Minutes)'])

plt.show()

# %%
plt.figure(figsize = (9,4))

sns.regplot(x='Rating', y='Runtime (Minutes)', data=df,scatter_kws ={'color':'red'}, line_kws={'color':'purple'})
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Runtime (Minutes)'>

# %%
df.corr(method = 'pearson') #(pearso,,spearman,kendal)
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.271592  -0.191869
# Year                         -0.126790  -0.079305
# Runtime (Minutes)             0.267953   0.211978
# Rating                        0.217654   0.631897
# Votes                         0.639661   0.325684
# ...

# %%
correlation_matrix = df.corr(method = 'pearson')

# %%
plt.figures(figsize=(12,8))

sns.heatmap(correlation_matrix, annot = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31d8bf02659e> in <module>
# ----> 1 plt.figures(figsize=(12,8))
#       2
#       3 sns.heatmap(correlation_matrix, annot = True)
#
# NameError: name 'plt' is not defined

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        1
df_numerized
# Out:
#      Rank  Title  Genre  Description  Director  Actors  Year  \
# 0       1    287     11          110       265     184  2014
# 1       2    568     85          538       518     736  2012
# 2       3    655    195          880       391     418  2016
# 3       4    635     92          613       105     658  2016
# 4       5    673      7          220       136     971  2016
# ..    ...    ...    ...          ...       ...     ...   ...
# 995   996    612    144          273        69     160  2015
# 996   997    316    190          874       176     574  2007
# 997   998    668    170          742       324     794  2008
# 998   999    611     61          186       549      12  2014
# 999  1000    504    121          249        59     550  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# ...

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')

# %%
plt.figure(figsize= (15,6))

sns.heatmap(correlation_matrix, annot = True)
# Out:
# <AxesSubplot:>
