# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('IBMD Movie dataset.txt',delimiter = ',')
# before performimg certin actions, endeavour to look at the datatype, certain data types dont allow certain methods

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head()

# %%
df.tail()

# %%
df.head(-5)

# %%
df.info()

# %%
df.shape

# %%
## % of total is null
df.isnull().sum() * 100 /len(df)

# %% [markdown]
# ## Drop missing values

# %%
df.dropna(axis=0, inplace = True)

# %%
df.dropna(axis=1, inplace = True)

# %%
df

# %% [markdown]
# ## Check for duplicates

# %%
df.duplicated().sum()

# %%
##
df.describe()

# %%
## Lets say we want to replace empty values with NaN
# df.replace('--',np.nan)

# %% [markdown]
# ## Display the title of movie having runtime >= 180miutes

# %%
df[df['Runtime (Minutes)'] >= 180]['Title']

# %% [markdown]
# ## in which year was there the highest average voting

# %%
df.groupby('Year')['Votes'].mean().sort_values(ascending=False)

# %%
sns.barplot(x='Year',y='Votes',data= df)
plt.title('Votes By Year')

# %% [markdown]
# ## In which year was te highest average revenue

# %%
df.head()

# %%
df.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data= df)
plt.title('Votes By Year')

# %% [markdown]
# ## find the average rating for each director

# %%
df.groupby('Director')['Rating'].mean().sort_values(ascending=False)

# %% [markdown]
# ## Display the top 10 lenghty films

# %%
df.head()

# %%
df.groupby('Title')['Runtime (Minutes)'].sum().sort_values(ascending=False).head(10)

# %%
#sns.barplot(x='Y',y='Revenue (Millions)',data= df)
#plt.title('Votes By Year')

# %% [markdown]
# ## Display Number of Movies Per Year

# %%
df.groupby('Year')['Title'].count()

# %%
df['Year'].value_counts()

# %%
sns.countplot(x='Year',data= df)
plt.title('Number of Movies Per Year')
plt.show()

# %% [markdown]
# ## Find the Most Popular Movie Title (Highest Revenue)

# %%
df.head()

# %%
df.groupby('Title')['Revenue (Millions)'].sum().sort_values(ascending=False)

# %% [markdown]
# ## Display Top 10 Highest Rated Movie Title and its Directors

# %%
df.head(1)

# %%
top10 = df.nlargest(10,'Rating')[['Director','Rating','Title']]
top = top10.set_index('Title')
top

# %%
sns.barplot(x='Rating',y=top.index,data=top)

# %% [markdown]
# ## Display Top 10 Highest Revenue Movie Title

# %%
t10 = df.groupby('Title')['Revenue (Millions)'].sum().sort_values(ascending = False).head(10)
t10=t10.to_frame()

# %%
sns.barplot(x='Revenue (Millions)',y=t10.index,data=t10)

# %% [markdown]
# ## Find average Movie rating per year

# %%
df.groupby('Year')['Rating'].mean().sort_values(ascending = False)#.head(10)

# %% [markdown]
# ## Does rating affect the revenue

# %%
# to answer this question ew'd need use a scatter plot 
sns.scatterplot(x='Rating',y='Revenue (Millions)', data=df)

# %% [markdown]
# ## Classify Movies based on Ratings into Excellent, Good, Average

# %%
## we could use the map here but cause of the number of ratings and the form it appeared in 
df.info()

# %%
def ratings(rate):#Rating could have been anything actualy ooo its the rating in the bracket 
#that matters and if we had made the rating in the bracket something else we must take that something else
    if rate >= 7.0:
        return 'Excellent'
    elif rate >= 6.0:
        return 'Average'
    else:
        return'Good'
# remeber to always use return here not print() cause we assigning it to a variable. Else it'd just print it once

# %%
df['rating_cal3'] = df['Rating'].apply(ratings) # map() would also work cause we dealing with one column

# %%
df

# %% [markdown]
# ##  Count number of Action Movies

# %%
df.info()

# %%
# before performimg certin actions, endeavour to look at the datatype, certain data types dont allow certain methods
df['Genre'].dtype

# %%
## because the Genre column ids of the obect data type, we can use str.contain to work on it 
df[df['Genre'].str.contains('Action')] ## # if we not sure of the form we can use case = False

# %% [markdown]
# ## Find unique values from Genre

# %%
##  if we run it like this we'd get each of the genres but not the unique vales
df['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %%
df[df['Genre'].str.contains('Action')]
# Out:
#      Rank                           Title                       Genre  \
# 0       1         Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 4       5                   Suicide Squad    Action,Adventure,Fantasy
# 5       6                  The Great Wall    Action,Adventure,Fantasy
# 8       9              The Lost City of Z  Action,Adventure,Biography
# 12     13                       Rogue One     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 958   959                  3 Days to Kill       Action,Drama,Thriller
# 968   969                         Wrecker      Action,Horror,Thriller
# 969   970                 The Lone Ranger    Action,Adventure,Western
# 990   991  Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 993   994        Resident Evil: Afterlife     Action,Adventure,Horror
#
#                                            Description            Director  \
# ...

# %% [markdown]
# df.groupby('Genre').sum()

# %%
##  even if we run it like this we'd just still be getting the number of eacg combo but not the disticnt values 
df['Genre'].value_counts()

# %%
df['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
## ist we' split this items by comma
list1 = [] # ist we create an empty list 
for value in df['Genre']: # we call the values inside the df['Genre']
    list1.append(value.split(',')) # then we start splitting the values in df['Genre'] and appending it to the created empty list

# %%
list1 # this gives us the spliteed df[Genre]
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy'],
# ...

# %%
## now we want to convert a 2D dataframe to 1D
one_d = [] # ist we create an empty list 
for item in list1: # we call the values inside the created list1 above
    for item1 in item: ## then we call the items in te 2D out
        one_d.append(item1) # then we start appending it to the created empty list

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
# ...

# %%
## after creating the one_d. There are 3 ways to now fid the unique values

# %%
##(!) this is one way. turn this one_d to a dataframe
one_dd = pd.DataFrame(one_d)
list(one_dd[0].unique()) ## then use the column name to find the unique values
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Crime',
#  'Western',
#  'War',
#  'Musical',
#  'Sport']

# %%
# (2) Another thing we can do is do a values count. Dataframe doesnt have the attribute . unique so we cant do 
# one_dd.unique() so rather we'd do this one_dd.value_counts()
one_dd.value_counts()
# Out:
# Drama        513
# Action       303
# Comedy       279
# Adventure    259
# Thriller     195
# Crime        150
# Romance      141
# Sci-Fi       120
# Horror       119
# Mystery      106
# Fantasy      101
# Biography     81
# Family        51
# Animation     49
# History       29
# Sport         18
# Music         16
# War           13
# Western        7
# Musical        5
# dtype: int64

# %%
##(3)
uniquelist = []
for item in one_d:
    if item not in uniquelist:
        uniquelist.append(item)
        
uniquelist
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Crime',
#  'Western',
#  'War',
#  'Musical',
#  'Sport']

# %% [markdown]
# ## How Many Films of Each Genre Were Made

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
## this would have helped us answer both questions at once
one_dd.value_counts()
# Out:
# Drama        513
# Action       303
# Comedy       279
# Adventure    259
# Thriller     195
# Crime        150
# Romance      141
# Sci-Fi       120
# Horror       119
# Mystery      106
# Fantasy      101
# Biography     81
# Family        51
# Animation     49
# History       29
# Sport         18
# Music         16
# War           13
# Western        7
# Musical        5
# dtype: int64

# %%
## we can also do this 
from collections import counter # this is another way to solve the problem but we'd need import the collections library

counter(one_d)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-8b7e4a4dea5b> in <module>
#       1 ## we can also do this
# ----> 2 from collections import counter
#       3
#       4 counter(one_d)
#
# ImportError: cannot import name 'counter' from 'collections' (C:\Anaconda\lib\collections\__init__.py)

# %% [markdown]
# ## this action isnt under this module but it is import

# %%
## Scenario here is that a certain row has values 4,900th but we want only 4900 without the comma(4,900) nd the th

## 4900th = 0,1,2,3,4,5 
data['Rank'] = data['Rank'].str[0:-2] #.str[0:3] -- to remove the th 
data['Rank'] = data['Rank'].str.replace(',','').astype('int') ## to remove the , and convert it to int

# remember that all these was possible cause the datatype of that column was initially a string

# %% [markdown]
# ## this action isnt under this module but it is import

# %%
## also not in this module 

## 1) changing column data types -- use .astype('datatype')
## 2) Mapping --  use to subsititute values. If the number of values are small we can simplu=y use mapping 
# if not we can use the if else statement

# %% [markdown]
# ## this action isnt under this module but it is import

# %%
## to show correlation matrix


# data.corr() -- using this we can easily see how much dependency each values have on each other. Anotherv method we cold have done this is by using scatter plot
